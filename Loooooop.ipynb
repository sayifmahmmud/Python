# %% [markdown]
# Loooopppp

# %%
from IPython.display import Image
Image('Screenshot(1).png')

# %% [markdown]
# 1

# %%
show=range(-100,-10)
for i in show:
    print(i)

# %% [markdown]
# 2

# %%
prime= range(10,1000)
sum=0
for i in prime:
    sum=sum+i
    #print(sum,i)

print('sum:',sum)
# Out:
# sum: 499455

# %% [markdown]
# 3

# %%
n=int(input('Enter your number:'))
fact=1

for i in range(1,n+1):
    fact= fact*i
print('The factorial is:',fact)
# Out:
# Enter your number: 7
# The factorial is: 5040

# %% [markdown]
# 4

# %%
number =( input('Enter your number:'))
for i in reversed(number):
     print(i,end='')
# Out:
# Enter your number: sayif sama
# amas fiyas

# %% [raw]
# Nested Loop

# %%
row=4

for i in range(1, row+1):
    for k in range(1, i+1):
        print('#',end='')
    print('')
# Out:
# #
# ##
# ###
# ####

# %%
n=6

for i in range(n):  #fixes the row
    for j in range(i,n):  #fixes the column
        print(' ',end=' ')

    for j in range(i+1):
        print('* ',end='')

    print()
# Out:
#             *
#           * *
#         * * *
#       * * * *
#     * * * * *
#   * * * * * *

# %%
n=6

for i in range(n):
    for j in range(i+1):
        print('*',end=' ')

    print()
# Out:
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *

# %%
n=6

for i in range(n):
    for j in range(i,n):
        print(' ',end=' ')

    for j in range(i+1):
        print('* ',end='')

    for j in range(i):
        print('* ',end='')

    print()
# Out:
#             *
#           * * *
#         * * * * *
#       * * * * * * *
#     * * * * * * * * *
#   * * * * * * * * * * *

# %%
n=6

for i in range(n):
    for j in range(i+1):
        print(' ',end=' ')

    for j in range(i,n-1):
        print('* ',end='')

    for j in range(i,n):
        print('* ',end='')

    print()
# Out:
#   * * * * * * * * * * *
#     * * * * * * * * *
#       * * * * * * *
#         * * * * *
#           * * *
#             *

# %%
n=6

for i in range(n-1):
    for j in range(i,n):
        print(' ',end=' ')

    for j in range(i+1):
        print('* ',end='')

    for j in range(i):
        print('* ',end='')

    print()

for i in range(n):
    for j in range(i+1):
        print(' ',end=' ')

    for j in range(i,n-1):
        print('* ',end='')

    for j in range(i,n):
        print('* ',end='')

    print()
# Out:
#             *
#           * * *
#         * * * * *
#       * * * * * * *
#     * * * * * * * * *
#   * * * * * * * * * * *
#     * * * * * * * * *
#       * * * * * * *
#         * * * * *
#           * * *
#             *
